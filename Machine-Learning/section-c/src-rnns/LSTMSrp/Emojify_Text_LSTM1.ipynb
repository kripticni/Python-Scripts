# %% [markdown]
# ![image](https://github.com/Coding-Lane/Emojify-Text/blob/main/emoji.png?raw=true)

# %%
#!pip install emoji

# %%
import numpy as np
import pandas as pd
import emoji

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, SimpleRNN, Embedding

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-12-07 00:06:08.742143: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-07 00:06:08.745172: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-07 00:06:08.755470: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733526368.772917   66089 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733526368.778030   66089 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 00:06:08.795900: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = pd.read_csv('Train.csv', header = None)
data.head()
# Out:
#                                    0  1
# 0  Francuski makaruni su tako ukusni  4
# 1                   1. rad je užasan  3
# 2                   Uznemiren sam!!!  3
# 3                      baciti loptu?  1
# 4                     Dobra   šala    2

# %%
emoji_dict = {
    0: ":red_heart:",
    1: ":baseball:",
    2: ":grinning_face_with_big_eyes:",
    3: ":disappointed_face:",
    4: ":fork_and_knife_with_plate:"
}

def label_to_emoji(label):
    return emoji.emojize(emoji_dict[label])

# %%
X = data[0].values
Y = data[1].values

# %%
file = open('cc.sh.300.vec', 'r', encoding = 'utf8')
content = file.readlines()
file.close()

# content

# %%
embeddings = {}

for line in content:
    line = line.split()
    embeddings[line[0]] = np.array(line[1:], dtype = float)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
word2index = tokenizer.word_index

# %%
Xtokens = tokenizer.texts_to_sequences(X)

# %%
word2index
# Out:
# {'je': 1,
#  'da': 2,
#  'sam': 3,
#  'se': 4,
#  'tako': 5,
#  'ha': 6,
#  'na': 7,
#  'mi': 8,
#  'volim': 9,
#  'li': 10,
#  'su': 11,
#  'želim': 12,
#  'u': 13,
#  'za': 14,
#  'on': 15,
#  'ona': 16,
#  'bejzbol': 17,
#  'prestani': 18,
#  'sa': 19,
#  'moj': 20,
#  'smešno': 21,
#  'loše': 22,
#  'ovo': 23,
#  'što': 24,
#  'mnogo': 25,
#  'ste': 26,
#  'ne': 27,
#  'si': 28,
#  'čestitam': 29,
#  'loptu': 30,
#  'hranu': 31,
#  'niste': 32,
#  'smo': 33,
#  'bravo': 34,
#  'bilo': 35,
#  'ja': 36,
#  'lol': 37,
#  'dobio': 38,
#  'i': 39,
#  'nedostaješ': 40,
#  'večeru': 41,
#  'ova': 42,
#  'te': 43,
#  'me': 44,
#  'jedem': 45,
#  'ga': 46,
#  'šala': 47,
#  'koja': 48,
#  'vaša': 49,
#  'igra': 50,
#  'uspeli': 51,
#  'ću': 52,
#  'nikad': 53,
#  'nisam': 54,
#  'rekao': 55,
#  'gde': 56,
#  'imam': 57,
#  'može': 58,
#  'dobro': 59,
#  'ovu': 60,
#  'tvoja': 61,
#  'dobila': 62,
#  'hoćeš': 63,
#  'dan': 64,
#  'imaš': 65,
#  'voli': 66,
#  'mnom': 67,
#  'nedostaje': 68,
#  'hrana': 69,
#  'život': 70,
#  'toliko': 71,
#  'smejem': 72,
#  'uradio': 73,
#  'posao': 74,
#  'vičeš': 75,
#  'mene': 76,
#  'ponosan': 77,
#  'odlična': 78,
#  'moja': 79,
#  'ljubav': 80,
#  'radi': 81,
#  'smeje': 82,
#  'pse': 83,
#  'ovaj': 84,
#  'bio': 85,
#  'svog': 86,
#  'devojka': 87,
#  'uzbuđen': 88,
#  'nije': 89,
#  'zabavan': 90,
#  'tebe': 91,
#  'kakav': 92,
#  'nisi': 93,
#  'sranje': 94,
#  'upravo': 95,
#  'francuski': 96,
#  'makaruni': 97,
#  'ukusni': 98,
#  '1': 99,
#  'rad': 100,
#  'užasan': 101,
#  'uznemiren': 102,
#  'baciti': 103,
#  'dobra': 104,
#  'omiljena': 105,
#  'skuvao': 106,
#  '23': 107,
#  '4': 108,
#  '20023': 109,
#  'meso': 110,
#  'zezaš': 111,
#  'kinesku': 112,
#  'hajdemo': 113,
#  'igramo': 114,
#  'ovoj': 115,
#  'vežbi': 116,
#  'juče': 117,
#  'opet': 118,
#  'izgubili': 119,
#  'tortu': 120,
#  'sirom': 121,
#  'zašto': 122,
#  'osećaš': 123,
#  'šalim': 124,
#  'zabava': 125,
#  'otkazana': 126,
#  'lopta': 127,
#  'frustriran': 128,
#  'rekla': 129,
#  'povišicu': 130,
#  'porodica': 131,
#  'sve': 132,
#  'baca': 133,
#  'do': 134,
#  'zvezda': 135,
#  'nazad': 136,
#  'voliš': 137,
#  'picu': 138,
#  'potpunosti': 139,
#  'zaslužujete': 140,
#  'nagradu': 141,
#  'sviđa': 142,
#  'jakna': 143,
#  'poklon': 144,
#  'biti': 145,
#  'valentine': 146,
#  'pali': 147,
#  'srednjem': 148,
#  'ko': 149,
#  'dole': 150,
#  'restoran': 151,
#  'zaljubljenih': 152,
#  'blizu': 153,
#  'sjajno': 154,
#  'super': 155,
#  'ništa': 156,
#  'uradi': 157,
#  'večeras': 158,
#  'imali': 159,
#  'divnu': 160,
#  'povrće': 161,
#  'zdravo': 162,
#  'dobar': 163,
#  'prijatelj': 164,
#  'više': 165,
#  'pričaj': 166,
#  'zabavljam': 167,
#  'možete': 168,
#  'poći': 169,
#  'nama': 170,
#  'želiš': 171,
#  'pridružiš': 172,
#  'večeri': 173,
#  'neverovatan': 174,
#  'pravim': 175,
#  'pauze': 176,
#  'neverovatno': 177,
#  'inteligentni': 178,
#  'talentovani': 179,
#  'dostignuća': 180,
#  'tužno': 181,
#  'nećeš': 182,
#  'doći': 183,
#  'pričaš': 184,
#  'gluposti': 185,
#  'najavu': 186,
#  'veliku': 187,
#  'vuču': 188,
#  'specijalizacija': 189,
#  'čekao': 190,
#  'dva': 191,
#  'sata': 192,
#  'potrebno': 193,
#  'joj': 194,
#  'večnost': 195,
#  'spremi': 196,
#  'baka': 197,
#  'mog': 198,
#  'života': 199,
#  'slaviću': 200,
#  'uskoro': 201,
#  'kod': 202,
#  'ali': 203,
#  'grejder': 204,
#  'dao': 205,
#  'nulu': 206,
#  'najslađa': 207,
#  'osoba': 208,
#  'koju': 209,
#  'ikada': 210,
#  'video': 211,
#  'obožavam': 212,
#  'svoje': 213,
#  'mama': 214,
#  'odličan': 215,
#  'kako': 216,
#  'usuđuješ': 217,
#  'to': 218,
#  'pitaš': 219,
#  'tip': 220,
#  'takva': 221,
#  'indijsku': 222,
#  'doljli': 223,
#  'danas': 224,
#  'popodne': 225,
#  'glupost': 226,
#  'nema': 227,
#  'granice': 228,
#  'tatu': 229,
#  'zagrliš': 230,
#  'bila': 231,
#  'zla': 232,
#  'šta': 233,
#  'redu': 234,
#  'tobom': 235,
#  'ljubazni': 236,
#  'prijateljski': 237,
#  'raspoloženi': 238,
#  'impresioniran': 239,
#  'vašom': 240,
#  'posvećenošću': 241,
#  'ovom': 242,
#  'projektu': 243,
#  'naručujem': 244,
#  'zvuči': 245,
#  'kao': 246,
#  'plan': 247,
#  'srećan': 248,
#  'zbog': 249,
#  'vic': 250,
#  'ubija': 251,
#  'haha': 252,
#  'kvalifikovani': 253,
#  'poziciju': 254,
#  'draga': 255,
#  'vidim': 256,
#  'posle': 257,
#  'vremena': 258,
#  'najbolji': 259,
#  'igrač': 260,
#  'trenutak': 261,
#  'algoritam': 262,
#  'njen': 263,
#  'osmeh': 264,
#  'šarmantan': 265,
#  'najgori': 266,
#  'mom': 267,
#  'životu': 268,
#  'zgodan': 269,
#  'niko': 270,
#  'privlačna': 271,
#  'sladak': 272,
#  'položili': 273,
#  'ispit': 274,
#  'mislim': 275,
#  'završiti': 276,
#  'hajde': 277,
#  'jedemo': 278,
#  'zajedno': 279,
#  'šteta': 280,
#  'ovde': 281,
#  'igram': 282,
#  'ti': 283,
#  'gubitnik': 284,
#  'umirem': 285,
#  'od': 286,
#  'gladi': 287,
#  'mogli': 288,
#  'rešite': 289,
#  'izgubio': 290,
#  'novčanik': 291,
#  'odgovorila': 292,
#  'tekst': 293,
#  'taj': 294,
#  'hvatač': 295,
#  'vidimo': 296,
#  'restoranu': 297,
#  'kuvao': 298,
#  'pirinač': 299,
#  'slatkiši': 300,
#  'završila': 301,
#  'prvi': 302,
#  'čovek': 303,
#  'iz': 304,
#  'baze': 305,
#  'prihvatanju': 306,
#  'zadatak': 307,
#  'predugačak': 308,
#  'ponizila': 309,
#  'sestra': 310,
#  'predavanja': 311,
#  'ipak': 312,
#  'domaći': 313,
#  'beba': 314,
#  'divna': 315,
#  'nedostajao': 316,
#  'tražim': 317,
#  'sastanak': 318,
#  'grozan': 319,
#  'predlog': 320,
#  'srećna': 321,
#  'uvek': 322,
#  'radim': 323,
#  'lošu': 324,
#  'ocenu': 325,
#  'suši': 326,
#  'čikaški': 327,
#  'mladunci': 328,
#  'ponovo': 329,
#  'pobedili': 330,
#  'odobrenje': 331,
#  'kolačići': 332,
#  'dobri': 333,
#  'mrzim': 334,
#  'idem': 335,
#  'stadion': 336,
#  'veoma': 337,
#  'razočaran': 338,
#  'zauvek': 339,
#  'zeza': 340,
#  'novom': 341,
#  'poslu': 342,
#  'uživajte': 343,
#  'pauzi': 344,
#  'odlazi': 345,
#  'radio': 346,
#  'tokom': 347,
#  'rođendana': 348,
#  'bebu': 349,
#  'gladan': 350,
#  'najdraža': 351,
#  'slatka': 352,
#  'doručkovao': 353,
#  'pas': 354,
#  'imao': 355,
#  'nekoliko': 356,
#  'štenaca': 357,
#  'sviđaš': 358,
#  'morao': 359,
#  'napravi': 360,
#  'houmran': 361,
#  'utakmici': 362,
#  'jesi': 363,
#  'ozbiljan': 364,
#  'šališ': 365}

# %%
Y_integers = []
for value in Y:
    try:
        Y_integers.append(int(value))
    except ValueError:
        Y_integers.append(0)
Ytrain = to_categorical(Y_integers)

# %%
def get_maxlen(data):
    maxlen = 0
    for sent in data:
        maxlen = max(maxlen, len(sent))
    return maxlen

maxlen = get_maxlen(Xtokens)
print(maxlen)
# Out:
# 9

# %%
Xtrain = pad_sequences(Xtokens, maxlen = maxlen,  padding = 'post', truncating = 'post')

# %% [markdown]
# # Model

# %%
embed_size = 300
embedding_matrix = np.zeros((len(word2index)+1, embed_size))

for word, i in word2index.items():
    try:
         embed_vector = embeddings[word]
         embedding_matrix[i] = embed_vector
    except:   
         continue

# %%
embedding_matrix
# Out:
# array([[ 0.000e+00,  0.000e+00,  0.000e+00, ...,  0.000e+00,  0.000e+00,
#          0.000e+00],
#        [-6.390e-02,  2.600e-02, -3.260e-02, ...,  1.560e-02,  7.870e-02,
#         -5.050e-02],
#        [-3.800e-03,  4.610e-02, -1.440e-02, ..., -4.400e-02,  2.810e-02,
#         -6.590e-02],
#        ...,
#        [ 4.330e-02,  2.960e-02,  1.550e-02, ..., -9.220e-02,  2.660e-02,
#          2.068e-01],
#        [ 2.580e-02, -1.790e-02,  2.000e-04, ...,  3.760e-02, -3.990e-02,
#          4.130e-02],
#        [ 0.000e+00,  0.000e+00,  0.000e+00, ...,  0.000e+00,  0.000e+00,
#          0.000e+00]])

# %%
model = Sequential([
    Embedding(input_dim = len(word2index) + 1,
              output_dim = embed_size,
              input_length = maxlen,
              weights = [embedding_matrix],
              trainable = False
             ),
    
    LSTM(units = 16, return_sequences = True),
    LSTM(units = 10),
    Dense(5, activation = 'softmax')
])

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# /home/mixie/anaconda3/envs/Env31207/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2024-12-07 00:07:40.438907: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.fit(Xtrain, Ytrain, epochs = 100)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3124 - loss: 1.6059
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3138 - loss: 1.5935
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3347 - loss: 1.5832
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3030 - loss: 1.5692
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2769 - loss: 1.5594
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3487 - loss: 1.5228
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3360 - loss: 1.4935
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3547 - loss: 1.4994
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3297 - loss: 1.4939
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3366 - loss: 1.4688
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4012 - loss: 1.4489
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4299 - loss: 1.4146
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4234 - loss: 1.4090
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4263 - loss: 1.3806
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4588 - loss: 1.3260
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4443 - loss: 1.3159
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4405 - loss: 1.2899
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.